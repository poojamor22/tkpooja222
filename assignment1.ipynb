# %% [markdown]
# Q1. Create one variable containing following type of data:
# (i) string
# (ii) list
# (iii) float
# (iv) tuple
#
# Ans:-(i) a="pooja"
# (ii) l=[1,2,3,4,5]
# (iii) a= 12.5
# (iv) t=("pooja","tannu")
#
# Q2. Given are some following variables containing data:
# (i) var1 = ‘ ‘
# (ii) var2 = ‘[ DS , ML , Python]’
# (iii) var3 = [ ‘DS’ , ’ML’ , ‘Python’ ]
# (iv) var4 = 1.
# What will be the data type of the above given variable.
#
# Ans:-(i) it is a one space variable in python.
# (ii) it is a improper list of strings.
# (iii) it is a proper list of strings .
# (iv) it is a integer type variable.
#
# Q3. Explain the use of the following operators using an example:
# (i) /
# (ii) %
# (iii) //
# (iv) **
#
#
# Ans:-(i) / :-it is a division operator used to perform division operation.
# example:-> 10/5
# output:-> 2
#
# (ii) % :- it is a modulo operator in python which provides the remainder after division.
# example:->  4%3
# output: 1
#
# (iii) // :- it is a floor division operator in python . It returns the quotient after division.
# example :-> 4//3
# output: 1
#
# (iv) ** :- it is exponential operator in python , used to  perform exponential operations .
# example:-> 2**3
# output:- 8
#
#
# Q4. Create a list of length 10 of your choice containing multiple types of data. Using for loop print the
# element and its data type.
#
# Ans: list=[1,2,3.5,"pooja",[20,30],{'name':'pooja','age':20},(1,2,3),None,{"pooja","tannu"},20]
# for i in list:
#     print(i , type(i))
#
# output:1 <class 'int'>
# 2 <class 'int'>
# 3.5 <class 'float'>
# pooja <class 'str'>
# [20, 30] <class 'list'>
# {'name': 'pooja', 'age': 20} <class 'dict'>
# (1, 2, 3) <class 'tuple'>
# None <class 'NoneType'>
# {'pooja', 'tannu'} <class 'set'>
# 20 <class 'int'>
#
#
# Q5. Using a while loop, verify if the number A is purely divisible by number B and if so then how many
# times it can be divisible.
#
# Ans:- A = int(input("Enter the value of A: "))
# B = int(input("Enter the value of B: "))
# while A % B == 0:
#     A = A / B
#     count += 1
#
# if count > 0:
#     print(f"A is divisible by B {count} times.")
# else:
#     print("A is not divisible by B.")
#
# output: Enter the value of A:  250
# Enter the value of B:  5
# A is divisible by B 3 times.
#
# Q6. Create a list containing 25 int type data. Using for loop and if-else condition print if the element is
# divisible by 3 or not.
#
# Ans: numbers = list(range(1, 26))
# for i in numbers:
#     if i % 3 == 0:
#         print(f"{i} is divisible by 3")
#     else:
#         print(f"{i} is not divisible by 3")
#
#
# output: 1 is not divisible by 3
# 2 is not divisible by 3
# 3 is divisible by 3
# 4 is not divisible by 3
# 5 is not divisible by 3
# 6 is divisible by 3
# 7 is not divisible by 3
# 8 is not divisible by 3
# 9 is divisible by 3
# 10 is not divisible by 3
# 11 is not divisible by 3
# 12 is divisible by 3
# 13 is not divisible by 3
# 14 is not divisible by 3
# 15 is divisible by 3
# 16 is not divisible by 3
# 17 is not divisible by 3
# 18 is divisible by 3
# 19 is not divisible by 3
# 20 is not divisible by 3
# 21 is divisible by 3
# 22 is not divisible by 3
# 23 is not divisible by 3
# 24 is divisible by 3
# 25 is not divisible by 3
#
#
# Q7. What do you understand about mutable and immutable data types? Give examples for both showing
# this property.
#
# Ans: Mutable : those data types in which we can make changes in the data are mutable data types .
# example:list
#
# immutable : those data types in which
